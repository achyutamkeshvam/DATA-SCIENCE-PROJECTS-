# %% [markdown]
# # football teams performance  analysis

# %% [markdown]
#  # our objective is to find best team among 288  teams without any data loss

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### excel sheet loaded

# %%
db1=pandas.read_excel("C:\\Users\\manu\\desktop\\Database\\a\\Database.xlsx", sheet_name="Team_Attributes")

# %% [markdown]
#  ## display  sheet as a dataframe

# %%
db1
# Out:
#         id  team_fifa_api_id  team_api_id       date  buildUpPlaySpeed  \
# 0        1               434         9930 2010-02-22                60
# 1        2               434         9930 2014-09-19                52
# 2        3               434         9930 2015-09-10                47
# 3        4                77         8485 2010-02-22                70
# 4        5                77         8485 2011-02-22                47
# 5        6                77         8485 2012-02-22                58
# 6        7                77         8485 2013-09-20                62
# 7        8                77         8485 2014-09-19                58
# 8        9                77         8485 2015-09-10                59
# 9       10               614         8576 2010-02-22                60
# 10      11               614         8576 2011-02-22                65
# 11      12               614         8576 2012-02-22                59
# ...

# %%
db1.head(5)
# Out:
#    id  team_fifa_api_id  team_api_id       date  buildUpPlaySpeed  \
# 0   1               434         9930 2010-02-22                60
# 1   2               434         9930 2014-09-19                52
# 2   3               434         9930 2015-09-10                47
# 3   4                77         8485 2010-02-22                70
# 4   5                77         8485 2011-02-22                47
#
#   buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0              Balanced                   NaN                    Little
# 1              Balanced                  48.0                    Normal
# 2              Balanced                  41.0                    Normal
# 3                  Fast                   NaN                    Little
# 4              Balanced                   NaN                    Little
#
#    buildUpPlayPassing buildUpPlayPassingClass           ...             \
# 0                  50                   Mixed           ...
# ...

# %%
db1.columns
# Out:
# Index(['id', 'team_fifa_api_id', 'team_api_id', 'date', 'buildUpPlaySpeed',
#        'buildUpPlaySpeedClass', 'buildUpPlayDribbling',
#        'buildUpPlayDribblingClass', 'buildUpPlayPassing',
#        'buildUpPlayPassingClass', 'buildUpPlayPositioningClass',
#        'chanceCreationPassing', 'chanceCreationPassingClass',
#        'chanceCreationCrossing', 'chanceCreationCrossingClass',
#        'chanceCreationShooting', 'chanceCreationShootingClass',
#        'chanceCreationPositioningClass', 'defencePressure',
#        'defencePressureClass', 'defenceAggression', 'defenceAggressionClass',
#        'defenceTeamWidth', 'defenceTeamWidthClass',
#        'defenceDefenderLineClass'],
#       dtype='object')

# %%
db1.shape
# Out:
# (1458, 25)

# %%
db1.tail(5)
# Out:
#       team_fifa_api_id  team_api_id       date  buildUpPlaySpeed  \
# 1453             15005        10000 2011-02-22                52
# 1454             15005        10000 2012-02-22                54
# 1455             15005        10000 2013-09-20                54
# 1456             15005        10000 2014-09-19                54
# 1457             15005        10000 2015-09-10                54
#
#      buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 1453              Balanced                   NaN                    Little
# 1454              Balanced                   NaN                    Little
# 1455              Balanced                   NaN                    Little
# 1456              Balanced                  42.0                    Normal
# 1457              Balanced                  42.0                    Normal
#
#       buildUpPlayPassing buildUpPlayPassingClass buildUpPlayPositioningClass  \
# ...

# %%
del(db1['id'])

# %%
df=db1.drop('team_fifa_api_id',axis=1)

# %%
df
# Out:
#       team_api_id       date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# 0            9930 2010-02-22                60              Balanced
# 1            9930 2014-09-19                52              Balanced
# 2            9930 2015-09-10                47              Balanced
# 3            8485 2010-02-22                70                  Fast
# 4            8485 2011-02-22                47              Balanced
# 5            8485 2012-02-22                58              Balanced
# 6            8485 2013-09-20                62              Balanced
# 7            8485 2014-09-19                58              Balanced
# 8            8485 2015-09-10                59              Balanced
# 9            8576 2010-02-22                60              Balanced
# 10           8576 2011-02-22                65              Balanced
# 11           8576 2012-02-22                59              Balanced
# 12           8576 2013-09-20                59              Balanced
# ...

# %% [markdown]
#  ## second sheet loaded as data frame

# %%
team=pandas.read_excel('C:\\Users\\manu\\desktop\\Database\\a\\Database.xlsx',sheet_name='Team')

# %%
team
# Out:
#         id  team_api_id  team_fifa_api_id           team_long_name  \
# 0        1         9987             673.0                 KRC Genk
# 1        2         9993             675.0             Beerschot AC
# 2        3        10000           15005.0         SV Zulte-Waregem
# 3        4         9994            2007.0         Sporting Lokeren
# 4        5         9984            1750.0        KSV Cercle Brugge
# 5        6         8635             229.0           RSC Anderlecht
# 6        7         9991             674.0                 KAA Gent
# 7        8         9998            1747.0                RAEC Mons
# 8        9         7947               NaN            FCV Dender EH
# 9       10         9985             232.0        Standard de Liège
# 10      11         8203          110724.0              KV Mechelen
# 11      12         8342             231.0           Club Brugge KV
# 12      13         9999             546.0            KSV Roeselare
# ...

# %% [markdown]
#  ## team names with their id's

# %%
team1=team[['team_short_name','team_api_id']]

# %%
team1
# Out:
#     team_short_name  team_api_id
# 0               GEN         9987
# 1               BAC         9993
# 2               ZUL        10000
# 3               LOK         9994
# 4               CEB         9984
# 5               AND         8635
# 6               GEN         9991
# 7               MON         9998
# 8               DEN         7947
# 9               STL         9985
# 10              MEC         8203
# 11              CLB         8342
# 12              ROS         9999
# 13              KOR         8571
# 14              TUB         4049
# 15              MOU         9996
# 16              WES        10001
# 17              CHA         9986
# 18              STT         9997
# 19              LIE         9989
# 20              EUP         6351
# 21              O-H         1773
# 22              WAA         8475
# 23              OOS         8573
# 24              MOP       274581
# 25              MUN        10260
# 26              NEW        10261
# ...

# %% [markdown]
#   ## merge both dataframes to match there corresponding attributes

# %%
df1=pandas.merge(df,team1,on='team_api_id')

# %%
df1
# Out:
#       team_api_id       date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# 0            9930 2010-02-22                60              Balanced
# 1            9930 2014-09-19                52              Balanced
# 2            9930 2015-09-10                47              Balanced
# 3            8485 2010-02-22                70                  Fast
# 4            8485 2011-02-22                47              Balanced
# 5            8485 2012-02-22                58              Balanced
# 6            8485 2013-09-20                62              Balanced
# 7            8485 2014-09-19                58              Balanced
# 8            8485 2015-09-10                59              Balanced
# 9            8576 2010-02-22                60              Balanced
# 10           8576 2011-02-22                65              Balanced
# 11           8576 2012-02-22                59              Balanced
# 12           8576 2013-09-20                59              Balanced
# ...

# %%
df1.get_dtype_counts()
# Out:
# datetime64[ns]     1
# float64            1
# int64              9
# object            13
# dtype: int64

# %% [markdown]
#  ## form 2 data frames 1 of string type another with all  numerical  values

# %%
df_string=df1.select_dtypes(include=['object'])

# %%
df_string
# Out:
#      buildUpPlaySpeedClass buildUpPlayDribblingClass buildUpPlayPassingClass  \
# 0                 Balanced                    Little                   Mixed
# 1                 Balanced                    Normal                   Mixed
# 2                 Balanced                    Normal                   Mixed
# 3                     Fast                    Little                    Long
# 4                 Balanced                    Little                   Mixed
# 5                 Balanced                    Little                   Mixed
# 6                 Balanced                    Little                   Mixed
# 7                 Balanced                    Normal                   Mixed
# 8                 Balanced                    Normal                   Mixed
# 9                 Balanced                    Little                   Mixed
# 10                Balanced                    Little                   Mixed
# ...

# %%
#excluding object data type column

# %%
df_numerical=df1.select_dtypes(exclude=['object'])

# %%
df_numerical
# Out:
#       team_api_id       date  buildUpPlaySpeed  buildUpPlayDribbling  \
# 0            9930 2010-02-22                60                   NaN
# 1            9930 2014-09-19                52                  48.0
# 2            9930 2015-09-10                47                  41.0
# 3            8485 2010-02-22                70                   NaN
# 4            8485 2011-02-22                47                   NaN
# 5            8485 2012-02-22                58                   NaN
# 6            8485 2013-09-20                62                   NaN
# 7            8485 2014-09-19                58                  64.0
# 8            8485 2015-09-10                59                  64.0
# 9            8576 2010-02-22                60                   NaN
# 10           8576 2011-02-22                65                   NaN
# 11           8576 2012-02-22                59                   NaN
# 12           8576 2013-09-20                59                   NaN
# ...

# %%
 df_string['team_short_name']
# Out:
# 0       AAR
# 1       AAR
# 2       AAR
# 3       ABE
# 4       ABE
# 5       ABE
# 6       ABE
# 7       ABE
# 8       ABE
# 9       AJA
# 10      AJA
# 11      AJA
# 12      AJA
# 13      AJA
# 14      AJA
# 15      ACM
# 16      ACM
# 17      ACM
# 18      ACM
# 19      ACM
# 20      ACM
# 21      ACA
# 22      ACA
# 23      ACA
# 24      ACA
# 25      ACA
# 26      ACA
# 27      HAA
# 28      HAA
# 29      HAA
#        ...
# 1428    XAM
# 1429    XER
# 1430    XER
# 1431    XER
# 1432    XER
# 1433     YB
# 1434     YB
# 1435     YB
# 1436     YB
# 1437     YB
# 1438     YB
# 1439    ZAG
# 1440    ZAG
# 1441    ZAG
# 1442    ZAG
# 1443    ZAG
# 1444    ZAR
# 1445    ZAR
# 1446    ZAR
# 1447    ZAR
# 1448    ZAR
# 1449    ZAR
# 1450    ZAW
# 1451    ZAW
# 1452    ZUL
# 1453    ZUL
# 1454    ZUL
# 1455    ZUL
# 1456    ZUL
# 1457    ZUL
# Name: team_short_name, Length: 1458, dtype: object

# %%
df_numerical.iloc[:,2:-1].shape
# Out:
# (1458, 9)

# %% [markdown]
#  ## formation  of small data frame  to   make  charts on it

# %%
smalldf=df_numerical.iloc[:50,:]

# %%
smalldf.columns
# Out:
# Index(['team_api_id', 'date', 'buildUpPlaySpeed', 'buildUpPlayDribbling',
#        'buildUpPlayPassing', 'chanceCreationPassing', 'chanceCreationCrossing',
#        'chanceCreationShooting', 'defencePressure', 'defenceAggression',
#        'defenceTeamWidth', 'team_short_name'],
#       dtype='object')

# %%
sns.barplot(x="defenceAggression", y="team_short_name", data=smalldf)

# %%
sns.swarmplot(x="defenceAggression", y="team_short_name", data=smalldf)

# %%
df_numerical
# Out:
#       team_api_id       date  buildUpPlaySpeed  buildUpPlayDribbling  \
# 0            9930 2010-02-22                60                   NaN
# 1            9930 2014-09-19                52                  48.0
# 2            9930 2015-09-10                47                  41.0
# 3            8485 2010-02-22                70                   NaN
# 4            8485 2011-02-22                47                   NaN
# 5            8485 2012-02-22                58                   NaN
# 6            8485 2013-09-20                62                   NaN
# 7            8485 2014-09-19                58                  64.0
# 8            8485 2015-09-10                59                  64.0
# 9            8576 2010-02-22                60                   NaN
# 10           8576 2011-02-22                65                   NaN
# 11           8576 2012-02-22                59                   NaN
# 12           8576 2013-09-20                59                   NaN
# ...

# %%
df_numerical.shape
# Out:
# (1458, 12)

# %%
sns.barplot(x='team_api_id',y='buildUpPlaySpeed',data=df_numerical)

# %% [markdown]
#  ## taking the mean of  performances of each team  in diffrent years

# %%
df_num1=df_numerical.groupby(['team_api_id'] , axis =0).mean()

# %%
df_numerical.columns
# Out:
# Index(['team_api_id', 'date', 'buildUpPlaySpeed', 'buildUpPlayDribbling',
#        'buildUpPlayPassing', 'chanceCreationPassing', 'chanceCreationCrossing',
#        'chanceCreationShooting', 'defencePressure', 'defenceAggression',
#        'defenceTeamWidth', 'team_short_name'],
#       dtype='object')

# %%
df_numerical['team_short_name']=df_string['team_short_name']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_num1
# Out:
#              buildUpPlaySpeed  buildUpPlayDribbling  buildUpPlayPassing  \
# team_api_id
# 1601                47.333333                  48.0           46.166667
# 1773                52.000000                  51.0           50.000000
# 1957                47.166667                  54.0           52.666667
# 2033                49.000000                  62.0           48.400000
# 2182                60.333333                  52.5           49.000000
# 2183                32.750000                   NaN           44.250000
# 2186                41.400000                  50.0           46.200000
# 4087                52.000000                  43.0           50.600000
# 4170                48.000000                   NaN           34.000000
# 6269                60.000000                  57.0           50.750000
# 6351                50.000000                   NaN           55.000000
# 6391                54.500000                  53.0           52.000000
# ...

# %% [markdown]
# # resseting index

# %%
df_num2=df_num1.reset_index()

# %%
df_num2
# Out:
#      team_api_id  buildUpPlaySpeed  buildUpPlayDribbling  buildUpPlayPassing  \
# 0           1601         47.333333                  48.0           46.166667
# 1           1773         52.000000                  51.0           50.000000
# 2           1957         47.166667                  54.0           52.666667
# 3           2033         49.000000                  62.0           48.400000
# 4           2182         60.333333                  52.5           49.000000
# 5           2183         32.750000                   NaN           44.250000
# 6           2186         41.400000                  50.0           46.200000
# 7           4087         52.000000                  43.0           50.600000
# 8           4170         48.000000                   NaN           34.000000
# 9           6269         60.000000                  57.0           50.750000
# 10          6351         50.000000                   NaN           55.000000
# ...

# %%
df_numerical[df_numerical.team_api_id==2183]
# Out:
#       team_api_id       date  buildUpPlaySpeed  buildUpPlayDribbling  \
# 997          2183 2010-02-22                30                   NaN
# 998          2183 2011-02-22                33                   NaN
# 999          2183 2012-02-22                34                   NaN
# 1000         2183 2013-09-20                34                   NaN
#
#       buildUpPlayPassing  chanceCreationPassing  chanceCreationCrossing  \
# 997                   40                     45                      40
# 998                   47                     69                      40
# 999                   45                     39                      67
# 1000                  45                     39                      52
#
#       chanceCreationShooting  defencePressure  defenceAggression  \
# 997                       70               55                 65
# 998                       53               55                 34
# ...

# %%
df_num2=df_num2.fillna(df_num2.mean())

# %%
df_num2
# Out:
#      team_api_id  buildUpPlaySpeed  buildUpPlayDribbling  buildUpPlayPassing  \
# 0           1601         47.333333             48.000000           46.166667
# 1           1773         52.000000             51.000000           50.000000
# 2           1957         47.166667             54.000000           52.666667
# 3           2033         49.000000             62.000000           48.400000
# 4           2182         60.333333             52.500000           49.000000
# 5           2183         32.750000             48.562977           44.250000
# 6           2186         41.400000             50.000000           46.200000
# 7           4087         52.000000             43.000000           50.600000
# 8           4170         48.000000             48.562977           34.000000
# 9           6269         60.000000             57.000000           50.750000
# 10          6351         50.000000             48.562977           55.000000
# ...

# %%
df_num2.columns
# Out:
# Index(['team_api_id', 'buildUpPlaySpeed', 'buildUpPlayDribbling',
#        'buildUpPlayPassing', 'chanceCreationPassing', 'chanceCreationCrossing',
#        'chanceCreationShooting', 'defencePressure', 'defenceAggression',
#        'defenceTeamWidth'],
#       dtype='object')

# %% [markdown]
#  ## filterring the  best teams on a condition

# %%
#d1=df_num2.applymap(lambda x:x>50)
d1=df_num2.applymap(lambda x:x>50).all(axis=1)

# %%
d1.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 258    False
# 259    False
# 260    False
# 261    False
# 262    False
# 263    False
# 264    False
# 265    False
# 266    False
# 267    False
# 268    False
# 269    False
# 270    False
# 271    False
# 272    False
# 273    False
# 274    False
# 275    False
# 276    False
# 277    False
# 278    False
# 279    False
# 280    False
# 281    False
# 282    False
# 283    False
# 284    False
# 285    False
# 286    False
# 287    False
# Length: 288, dtype: bool

# %%
d1['teamname']=df_string['team_short_name']

# %% [markdown]
#  ## assigning  d1 to result column of df_num2

# %%
df_num2['Result']=d1

# %% [markdown]
#  ## fetching only true values

# %%
df_num2[df_num2['Result'] ==True]
# Out:
#      team_api_id  buildUpPlaySpeed  buildUpPlayDribbling  buildUpPlayPassing  \
# 201         9860         59.600000                  51.0           60.000000
# 225         9925         61.333333                  50.5           57.333333
#
#      chanceCreationPassing  chanceCreationCrossing  chanceCreationShooting  \
# 201              58.400000               63.800000               64.000000
# 225              55.666667               60.833333               60.833333
#
#      defencePressure  defenceAggression  defenceTeamWidth Result
# 201        53.400000          59.000000         61.400000   True
# 225        53.333333          54.333333         62.166667   True

# %% [markdown]
#  ## count plot for true and  false values

# %%
sns.countplot(x='Result', data=df_num2)

# %% [markdown]
#  ## pairplots to display corelation b/w diffrent attributes

# %%
sns.pairplot(df_num2.iloc[:,1:5])

# %%
sns.pairplot(df_num2.iloc[:,6:10])

# %% [markdown]
#  ## violin plots for diffrent  attributes

# %%
plt.subplot(3,3,1)
sns.violinplot(x='Result' ,y='buildUpPlaySpeed' , data=df_num2)

plt.subplot(3,3,2)
sns.violinplot(x='Result' ,y='buildUpPlayDribbling' , data=df_num2)

plt.subplot(3,3,3)
sns.violinplot(x='Result' ,y='buildUpPlayPassing' , data=df_num2)

plt.subplot(3,3,4)
sns.violinplot(x='Result' ,y='chanceCreationPassing' , data=df_num2)

plt.subplot(3,3,5)
sns.violinplot(x='Result' ,y='chanceCreationCrossing' , data=df_num2)

plt.subplot(3,3,6)
sns.violinplot(x='Result' ,y='chanceCreationShooting' , data=df_num2)

plt.subplot(3,3,7)
sns.violinplot(x='Result' ,y='defencePressure' , data=df_num2)

plt.subplot(3,3,8)
sns.violinplot(x='Result' ,y='defenceAggression' , data=df_num2)

plt.subplot(3,3,9)
sns.violinplot(x='Result' ,y='defenceTeamWidth' , data=df_num2)

plt.show()
